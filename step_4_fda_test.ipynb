# %% [markdown]
# # pip install requirements
#
# Remember to click on "Restart Runtime" before go on

# %%
# CosPlace requirements
# !pip3 install "faiss_cpu>=1.7.1"
# !pip3 install "numpy>=1.21.2"
# !pip3 install "Pillow>=9.0.1"
# !pip3 install "scikit_learn>=1.0.2"
# !pip3 install "torch>=1.8.2"
# !pip3 install "torchvision>=0.9.2"
# !pip3 install "tqdm>=4.62.3"
# !pip3 install "utm>=0.7.0"
# !pip3 install "timm"

import torch
#use GPU if available 
DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu") #'cpu' # 'cuda' or 'cpu'
print(DEVICE)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting faiss_cpu>=1.7.1
#   Downloading faiss_cpu-1.7.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 81.1 MB/s eta 0:00:00
# Installing collected packages: faiss_cpu
# Successfully installed faiss_cpu-1.7.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.8/dist-packages (1.21.6)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Pillow>=9.0.1
#   Downloading Pillow-9.4.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 33.7 MB/s eta 0:00:00
# Installing collected packages: Pillow
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
# Successfully installed Pillow-9.4.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: scikit_learn>=1.0.2 in /usr/local/lib/python3.8/dist-packages (1.0.2)
# Requirement already satisfied: numpy>=1.14.6 in /usr/local/lib/python3.8/dist-packages (from scikit_learn>=1.0.2) (1.21.6)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from scikit_learn>=1.0.2) (1.7.3)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit_learn>=1.0.2) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit_learn>=1.0.2) (3.1.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch>=1.8.2 in /usr/local/lib/python3.8/dist-packages (1.13.0+cu116)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch>=1.8.2) (4.4.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torchvision>=0.9.2 in /usr/local/lib/python3.8/dist-packages (0.14.0+cu116)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torchvision>=0.9.2) (4.4.0)
# Requirement already satisfied: torch==1.13.0 in /usr/local/lib/python3.8/dist-packages (from torchvision>=0.9.2) (1.13.0+cu116)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from torchvision>=0.9.2) (2.25.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.8/dist-packages (from torchvision>=0.9.2) (9.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from torchvision>=0.9.2) (1.21.6)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision>=0.9.2) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision>=0.9.2) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision>=0.9.2) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision>=0.9.2) (1.24.3)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tqdm>=4.62.3 in /usr/local/lib/python3.8/dist-packages (4.64.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting utm>=0.7.0
#   Downloading utm-0.7.0.tar.gz (8.7 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: utm
#   Building wheel for utm (setup.py) ... done
#   Created wheel for utm: filename=utm-0.7.0-py3-none-any.whl size=6108 sha256=623e4ab0f2bd078b2fd508fba4ffc73757ad35d0f8ffffe452c59cde8c134d09
#   Stored in directory: /root/.cache/pip/wheels/65/e2/d8/878a8cc986641056fbfebefc4d8eb64238a7b6d3426e86b447
# Successfully built utm
# Installing collected packages: utm
# Successfully installed utm-0.7.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting timm
#   Downloading timm-0.6.12-py3-none-any.whl (549 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 549.1/549.1 KB 17.2 MB/s eta 0:00:00
# Requirement already satisfied: torchvision in /usr/local/lib/python3.8/dist-packages (from timm) (0.14.0+cu116)
# Collecting huggingface-hub
#   Downloading huggingface_hub-0.11.1-py3-none-any.whl (182 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.4/182.4 KB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.8/dist-packages (from timm) (1.13.0+cu116)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.8/dist-packages (from timm) (6.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch>=1.7->timm) (4.4.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from huggingface-hub->timm) (4.64.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from huggingface-hub->timm) (3.9.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from huggingface-hub->timm) (2.25.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub->timm) (21.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.8/dist-packages (from torchvision->timm) (9.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from torchvision->timm) (1.21.6)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.9->huggingface-hub->timm) (3.0.9)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub->timm) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub->timm) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub->timm) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub->timm) (1.24.3)
# Installing collected packages: huggingface-hub, timm
# Successfully installed huggingface-hub-0.11.1 timm-0.6.12
# cuda:0

# %% [markdown]
# # Download Datasets and previous data

# %% [markdown]
# Downloading with gdown doesn't work properly.
#
# Prefer always to use drive / mount

# %%
import os
import gdown
from google.colab import drive

def download(id, output=None, quiet=True):
  gdown.download(
    f"https://drive.google.com/uc?export=download&confirm=pbef&id={id}",
    output=output,
    quiet=quiet
  )


use_mount = True
resume_model = False

if use_mount:
  drive.mount('/content/drive')

# TOKYO-XS DATASET
if not os.path.isdir("/content/tokyo_xs"):
  if use_mount:
    # !jar xvf "/content/drive/MyDrive/Project 6 - Dataset/tokyo-xs.zip"
  else:
    id = "1fBCnap5BRh36474cVkjvjlC-yUTEb1n3"
    download(id, quiet=False)                           # download from our gdrive
    # !jar xvf "/content/tokyo-xs.zip"                    # unzip
    # !rm -r "/content/tokyo-xs.zip"                      # remove .zip file

if not os.path.isdir("/content/tokyo_xs"):
  raise FileNotFoundError(f"Can't download tokyo xs")

#TOKYO NIGHT DATASET
if not os.path.isdir("/content/tokyo-night"):
  if use_mount:
    # !jar xvf "/content/drive/MyDrive/Project 6 - Dataset/tokyo-night.zip"
  else:
    id = "1EZJY2r5565-iVk2oEbTns0xc4F_em4Y4"
    download(id, quiet=False)                           # download from our gdrive
    # !jar xvf "/content/tokyo-night.zip"                    # unzip
    # !rm -r "/content/tokyo-night.zip"
  
if not os.path.isdir("/content/tokyo-night"):
    raise FileNotFoundError(f"Can't download tokyo night")
  
#TOKYO NIGHT DATASET - AUG1
if not os.path.isdir("/content/tokyo-night-aug"):
  if use_mount:
    # !jar xvf "/content/drive/MyDrive/Project 6 - Dataset/tokyo-night-aug.zip"
  else:
    id = "1QaDSN_SZKCiNM_wzrymCesFfxVabHLBa"
    download(id, quiet=False)                           # download from our gdrive
    # !jar xvf "/content/tokyo-night-aug.zip"                    # unzip
    # !rm -r "/content/tokyo-night-aug.zip"

if not os.path.isdir("/content/tokyo-night-aug"):
    raise FileNotFoundError(f"Can't download tokyo night aug1")

#TOKYO NIGHT DATASET - AUG2
if not os.path.isdir("/content/tokyo-night-aug-2"):
  if use_mount:
    # !jar xvf "/content/drive/MyDrive/Project 6 - Dataset/tokyo-night-aug-2.zip"
  else:
    id = "1BxCxGKusNK2Q5nWrLrDtXFH7MaSwZYgu"
    download(id, quiet=False)                           # download from our gdrive
    # !jar xvf "/content/tokyo-night-aug-2.zip"                    # unzip
    # !rm -r "/content/tokyo-night-aug-2.zip"

if not os.path.isdir("/content/tokyo-night-aug-2"):
  raise FileNotFoundError(f"Can't download tokyo night aug-2")

# SAN FRANCISCO - XS DATASET
if not os.path.isdir("/content/small"):
  if use_mount:
    # !jar xvf "/content/drive/MyDrive/Project 6 - Dataset/sf-xs.zip"
  else:
    id = "1brIxBJmOgvuzFbI57f5LxnMxjccUu993"
    download(id, quiet=False)                           # download
    # !jar xvf "/content/sf-xs.zip"                       # unzip
    # !rm -r "/content/sf-xs.zip"                         # remove .zip file

if not os.path.isdir("/content/small"):
  raise FileNotFoundError(f"Can't download sfxs")

# resumed model
if resume_model and not os.path.isfile("/content/saved_models/arcface_model.pth"):
  if use_mount:
    # !jar xvf "/content/drive/MyDrive/Project 6 - Dataset/saved_models.zip"

if resume_model and not os.path.isfile("/content/saved_models/sphereface_model.pth"):
  if use_mount:
    # !jar xvf "/content/drive/MyDrive/Project 6 - Dataset/saved_models.zip"

if resume_model and not os.path.isfile("/content/saved_models/cosface_model.pth"):
  if use_mount:
    # !jar xvf "/content/drive/MyDrive/Project 6 - Dataset/saved_models.zip"
# Out:
# Output streaming troncato alle ultime 5000 righe.
#  inflated: tokyo-night-aug/test/database/@0382344.43@3946975.94@54@S@035.65963@0139.70016@pC4OpE8tqNm0UCk-jIUclw@11@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382344.43@3946975.94@54@S@035.65963@0139.70016@pC4OpE8tqNm0UCk-jIUclw@04@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382187.39@3947191.02@54@S@035.66155@0139.69839@h1_wOyahxTW6Bd48a_aC2w@10@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381422.69@3946460.79@54@S@035.65487@0139.69006@OTFDfuo1jKzHITHEexITig@06@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381977.62@3946740.84@54@S@035.65746@0139.69614@bzmpNimh7ZJfDwv5qWYZMg@11@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382352.62@3946630.15@54@S@035.65651@0139.70030@3UfZUU0chud8cQsnfyCuhg@01@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382306.25@3947340.88@54@S@035.66291@0139.69969@F8cRDMX2wi1w6h_O5xIByw@09@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381438.34@3946867.94@54@S@035.65855@0139.69017@VX-kCHm9ICSjV9yfSxPqCw@06@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382067.28@3946660.34@54@S@035.65675@0139.69715@r5ZQiOkXKitoMUcGRkp83g@10@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382550.41@3947168.47@54@S@035.66139@0139.70241@5YcJo6ARlgdPPUtJ1eoP3Q@05@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382095.84@3947189.35@54@S@035.66152@0139.69738@svlF5dj9WfvIMU0fmWRsLQ@02@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382802.36@3947216.40@54@S@035.66185@0139.70518@YFW2GklG-fDYzpahPfoH2w@00@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382052.93@3946916.46@54@S@035.65906@0139.69695@7pC5mlkYW2ivoPuNnlgI1w@02@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382153.88@3946459.17@54@S@035.65495@0139.69813@ZphF6TWWd7GbRMdp1a8bEg@08@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382293.48@3946766.06@54@S@035.65773@0139.69963@o9ZcGERXcDIeVRS8yhmduQ@04@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382534.13@3947128.64@54@S@035.66103@0139.70223@z0EFp_WwbcuZcSxVXojePA@03@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381759.77@3947454.62@54@S@035.66387@0139.69363@wEmSt40wRGVRusQGfKr-rg@11@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382270.76@3946909.91@54@S@035.65902@0139.69936@_FO10XU8k0ll8NGJhymLFg@11@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381678.49@3946421.77@54@S@035.65455@0139.69289@MtYiUiOi6jscI4HSPoeM0g@01@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381979.63@3946564.98@54@S@035.65588@0139.69619@-BXN0g78TtoP69zQjDBGqA@00@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382619.24@3947019.57@54@S@035.66005@0139.70319@ksMep6ssJpqtI9AJHlUo9g@03@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381522.55@3947052.19@54@S@035.66022@0139.69107@gGKsRiIUsS_lHFLK6v18yA@08@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382655.72@3946812.97@54@S@035.65820@0139.70362@RFsiume23tq5xI7lJwpfkA@02@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382749.67@3946323.16@54@S@035.65379@0139.70473@3awlDL5EgLQq0I1kzu6JdQ@05@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381880.94@3946618.88@54@S@035.65635@0139.69509@ogKpA93j6_hvPCgh2Xgwjg@02@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382809.16@3947134.66@54@S@035.66111@0139.70527@p7rGGoy7Lfnq2Y_gV8FHvA@03@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382032.08@3946648.93@54@S@035.65664@0139.69676@CsGD36CF632YTo73bsjdPA@08@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382796.16@3946608.66@54@S@035.65637@0139.70520@34hKq03qxbprj245ylWfzw@07@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382178.10@3947029.40@54@S@035.66009@0139.69832@PD7p38xMsX5XJwSlBchKAQ@03@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382641.06@3946429.76@54@S@035.65474@0139.70352@scF1_mCtqmnoa6qgKQcsUA@03@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382364.57@3947369.61@54@S@035.66318@0139.70033@PpmD_4GmcIMD9S-5legn7A@05@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381434.51@3946138.58@54@S@035.65197@0139.69023@zShLxqxW5iNieA8K6cYVww@06@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382723.16@3947148.99@54@S@035.66123@0139.70432@tueSQ4hMRFxBH3wgFehjWQ@06@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382667.66@3946373.17@54@S@035.65423@0139.70382@2HY8McnT1ZY7wew0HlKxzg@09@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382147.39@3946919.31@54@S@035.65909@0139.69799@Ii4apDJmaqfSvP0r8-bOHA@02@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382324.68@3947474.75@54@S@035.66412@0139.69987@L_nPw2jfHoiPZ3_Id03wSw@06@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382250.77@3946876.67@54@S@035.65872@0139.69914@ofH-flAjZyU03yAIn5ccYQ@07@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382188.73@3946868.29@54@S@035.65864@0139.69846@Bqui7PyAiv1SvSJbfkstNA@04@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382188.73@3946868.29@54@S@035.65864@0139.69846@Bqui7PyAiv1SvSJbfkstNA@11@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381923.91@3946827.64@54@S@035.65824@0139.69554@u2uiMHvDicfPnkPNFefU-w@05@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382580.75@3946175.07@54@S@035.65244@0139.70289@oMqQT-oM1oLulLJMHBZKtA@07@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382305.55@3946945.39@54@S@035.65935@0139.69974@vM9fDeDgrouaRWTeHWTirg@06@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382690.40@3946676.50@54@S@035.65697@0139.70403@OWwvMoj8Yuo7IC14u8pdHg@03@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382403.37@3946640.58@54@S@035.65661@0139.70086@m6XSwRgy2696u8u2dqS9Hw@02@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382163.85@3947081.61@54@S@035.66056@0139.69815@r330qd4QlexeOurlmSirtg@10@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382362.06@3946714.12@54@S@035.65727@0139.70039@tnCxPuYVmwC3hiEpE3NdRw@09@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381955.72@3946571.18@54@S@035.65593@0139.69593@btEDQhQAUkGwG_XcXpnDRQ@08@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382113.52@3946604.25@54@S@035.65625@0139.69766@ILKrbCVSpxrT-JPNsd9Ing@00@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382170.22@3946906.36@54@S@035.65898@0139.69825@7GWc4Ik92q_x7ruLINpzWA@06@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382318.57@3947450.54@54@S@035.66390@0139.69981@JfOpmtStatPfb0oA5PoklA@05@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382318.57@3947450.54@54@S@035.66390@0139.69981@JfOpmtStatPfb0oA5PoklA@10@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382613.52@3947024.97@54@S@035.66010@0139.70313@t2rCNT0pJnAAAAAGOveJhg@02@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381765.31@3946530.11@54@S@035.65554@0139.69383@tNviM31kiC_J7q8o-pun7A@04@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382655.68@3946487.48@54@S@035.65526@0139.70367@etryELB1E6C7vZyAwDbc3g@01@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382575.65@3947380.14@54@S@035.66330@0139.70266@JLVkjaVhCY3s0y2kXQlO8g@08@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381987.49@3947000.31@54@S@035.65981@0139.69621@yOe9hc99H8Y1R-E76BS-Lw@03@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382407.58@3947062.08@54@S@035.66041@0139.70085@1pzI0mL_UygojsxGRb394g@08@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382923.26@3946565.60@54@S@035.65600@0139.70661@HUiEuFdSm8Q7QR4FCaIrIg@11@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382923.26@3946565.60@54@S@035.65600@0139.70661@HUiEuFdSm8Q7QR4FCaIrIg@04@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382176.22@3947113.51@54@S@035.66085@0139.69828@LShKxbsHwPsAAAQfCXnY3Q@10@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382176.22@3947113.51@54@S@035.66085@0139.69828@LShKxbsHwPsAAAQfCXnY3Q@05@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382280.18@3946766.23@54@S@035.65773@0139.69948@dKlbTDzs3ozjfjqqNTZz8g@03@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382171.39@3947022.50@54@S@035.66003@0139.69824@rxo6gWWnUlSXCpRX64u9gw@05@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381535.31@3947465.82@54@S@035.66395@0139.69115@779KXEA2Jv40K5vDT2nsMQ@02@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382084.37@3946584.01@54@S@035.65606@0139.69735@2rtZikmGdZ-Q8wZg52TmXw@08@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382405.44@3947139.54@54@S@035.66111@0139.70081@fjOEkRHByyXIC0edshmrYg@00@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382305.06@3946922.44@54@S@035.65914@0139.69973@xLQdjGoU-L1GLDxffj3Vzg@00@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382867.77@3946408.25@54@S@035.65457@0139.70602@a3XL19uY327sgEB8-1EobA@10@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382897.55@3946304.35@54@S@035.65364@0139.70637@xEe5pZItcSVb-Zunh1i7Sg@04@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382185.13@3947033.85@54@S@035.66013@0139.69839@0bTFtiVK2rznL84dfP40hQ@10@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382185.13@3947033.85@54@S@035.66013@0139.69839@0bTFtiVK2rznL84dfP40hQ@05@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381444.50@3946256.37@54@S@035.65303@0139.69033@4RFz8J1p4UoKdyCBGo5dUw@05@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381444.50@3946256.37@54@S@035.65303@0139.69033@4RFz8J1p4UoKdyCBGo5dUw@10@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382736.97@3946232.14@54@S@035.65297@0139.70460@zN7XGnMidWkGkbAWPyJHGg@05@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382624.35@3946967.58@54@S@035.65959@0139.70325@xentJ7eIJdXGL9GhYv1djQ@11@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382470.29@3946730.44@54@S@035.65743@0139.70159@3_ONv3vySjlWJGWPIngh0g@03@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382562.89@3946920.58@54@S@035.65915@0139.70258@CsTgE3BuiPgh-k0aHBApsQ@03@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381880.74@3947306.02@54@S@035.66255@0139.69499@8qFLVeImBurLJmgAnrf8Lw@08@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381892.56@3946587.33@54@S@035.65607@0139.69523@0PfRPeeDE4lkUTILnuVGiQ@09@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381436.08@3946881.84@54@S@035.65867@0139.69014@9vlKIAFf3nLkJQZqWGFg7Q@06@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382129.94@3947139.75@54@S@035.66108@0139.69777@MRFzQiUt0WdGl_gciZqI-w@00@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381652.06@3946442.87@54@S@035.65474@0139.69259@cvk39qYYdoVTzvMQ7SNlgg@11@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382718.42@3946768.54@54@S@035.65780@0139.70432@_LjHXrrAKUBijagF_qnSGA@06@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382316.77@3947273.95@54@S@035.66231@0139.69981@YjFw8Fkt7BnLOQMO_f81OQ@06@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382239.92@3946508.39@54@S@035.65540@0139.69907@rvbt-z_3v_5irN0MXJwDUg@10@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381949.75@3946796.57@54@S@035.65796@0139.69583@5L4FE7rGaJrtBoaSluz8bA@11@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381920.47@3946534.26@54@S@035.65560@0139.69554@OkTICMa4Is5xAzOYDLJexQ@01@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382124.60@3947098.78@54@S@035.66071@0139.69771@veF3kYynFNY-NfkMcO-e8Q@04@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381972.67@3946838.76@54@S@035.65835@0139.69607@ovL4PRjR6YsSXIW1sMCh2Q@03@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382426.71@3946604.99@54@S@035.65629@0139.70112@1V251BkUnmQtOqiVB3t5Ow@03@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382881.97@3946524.32@54@S@035.65562@0139.70616@qCWvi3V4YhUedRMBW1zCCQ@03@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382897.79@3947491.60@54@S@035.66434@0139.70620@attrc2p-ZznChYaokDjfZA@08@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381970.32@3946729.63@54@S@035.65736@0139.69606@NVFC18G7vCY6r_c3cZ3Pfw@01@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381595.31@3946552.89@54@S@035.65572@0139.69195@S81yuA9xqydSWbU8sFNFrg@06@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381812.92@3946957.92@54@S@035.65940@0139.69429@jDddtOCPT9AZQp582A-n2A@10@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382677.18@3947376.02@54@S@035.66327@0139.70378@NyTWsaeNyi1Dr1YpC_rbiA@09@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382142.61@3946230.23@54@S@035.65288@0139.69804@U3X4D21ggdtHoD0kVEvW1g@10@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381651.02@3946555.15@54@S@035.65575@0139.69256@mkqLkeqCWz_gPgaWWL-Bqw@03@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382421.48@3947257.04@54@S@035.66217@0139.70097@2IB6j93cGvJDWKvvgNdCHQ@11@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382142.61@3946230.23@54@S@035.65288@0139.69804@U3X4D21ggdtHoD0kVEvW1g@05@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382348.12@3946700.99@54@S@035.65715@0139.70024@Te2ZoriFkRM3y4K1WSJ-og@11@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381909.94@3946246.19@54@S@035.65300@0139.69547@4r4IKKzuVW8sq2vmi-C2cw@01@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382259.70@3946340.62@54@S@035.65389@0139.69932@boDFWDa3tDyq_wmoKpQarg@03@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382584.60@3946857.95@54@S@035.65859@0139.70283@sez3ALawviBWDGxT0w0vVg@04@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381556.85@3946310.12@54@S@035.65353@0139.69156@UptqYFkOaXcYd-ahPeDZuw@02@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381947.94@3947219.27@54@S@035.66177@0139.69575@ZhlcNICNu0drl_-q5UbLOA@05@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382486.87@3946477.84@54@S@035.65516@0139.70181@nsc1atuJqt6Zej_hewfDYg@06@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382661.86@3946612.98@54@S@035.65639@0139.70372@TRho_whCDR1AzFOmfASmxg@00@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382207.93@3946294.49@54@S@035.65347@0139.69875@PI4aIo31lak4kyPWzMCUQA@04@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381534.55@3946688.16@54@S@035.65694@0139.69126@b9rn5GFnRoXEI6IQO5t50w@01@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382769.72@3947116.65@54@S@035.66095@0139.70484@xvP7kstpVl-Vg4qPAlJYiQ@05@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382217.38@3947103.65@54@S@035.66076@0139.69874@oCX7q_gVzfX0cKq_svwqgQ@01@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382356.70@3946979.77@54@S@035.65966@0139.70030@igNyTHBZJ7kKHs4Q47e5Rg@03@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382266.52@3946985.96@54@S@035.65971@0139.69930@BDv1Y0tQX-YOlrfIHR57pA@09@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382086.31@3946682.83@54@S@035.65696@0139.69735@uh1exVYQpj8b-tsEMBDahQ@01@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381791.01@3946637.60@54@S@035.65651@0139.69410@qTswIlxD39Mwu8zEy68VOw@02@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381752.86@3946914.67@54@S@035.65900@0139.69364@nxEVTtbovThHSsrUL2NOew@11@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381996.23@3946587.73@54@S@035.65609@0139.69637@nunupNPEl6EUHHajkQPcjg@02@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382543.80@3946146.94@54@S@035.65218@0139.70248@-WbK7ZCI0nYUmn_J3gUUkw@01@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381436.51@3946906.90@54@S@035.65890@0139.69014@MoeYmqcYaQWjusmedhQfjw@10@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382352.65@3947173.41@54@S@035.66141@0139.70022@mQ3l-OfifQg__-06GSUb_g@06@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382285.61@3946978.38@54@S@035.65964@0139.69951@8Z2ZvY3xwNEERxF9oV-5RA@05@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381568.25@3946336.15@54@S@035.65377@0139.69168@WoQiTlbnf0K5jkQi4iCx_A@10@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382760.32@3947378.59@54@S@035.66331@0139.70470@2jVKwNhPTSay47_dnulFPQ@07@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381933.14@3946663.56@54@S@035.65676@0139.69566@9LkoSWDfXqKHp9BHWKFvPg@08@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382285.61@3946978.38@54@S@035.65964@0139.69951@8Z2ZvY3xwNEERxF9oV-5RA@10@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382204.31@3947060.44@54@S@035.66037@0139.69860@L4cn_v-ngifsQtoLO7lLPg@01@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382906.86@3947135.48@54@S@035.66113@0139.70635@OypFwLazXwDGayGr6iJtjg@01@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381744.78@3946953.50@54@S@035.65935@0139.69354@9kj3X9Lj09P5OKskRj_YVA@07@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382605.89@3946996.23@54@S@035.65984@0139.70305@Czv7oLaWKGBiRC14EG3Yug@07@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382343.56@3947163.44@54@S@035.66132@0139.70012@NEt2bjjDGCr69TE0T5eBNQ@06@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382405.28@3947223.30@54@S@035.66186@0139.70080@oyiIHIgVsRpEZRbaC0Iz1w@08@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382791.07@3946798.98@54@S@035.65809@0139.70512@nI-rdH8hXMhTnQP_3GqS8A@08@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381547.96@3946655.03@54@S@035.65664@0139.69141@dmP7dThIzQeYOVAEx7BZow@00@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382523.05@3947030.49@54@S@035.66014@0139.70213@vfkXenjOK3KaTwqpXXPl3Q@10@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382523.05@3947030.49@54@S@035.66014@0139.70213@vfkXenjOK3KaTwqpXXPl3Q@05@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382697.42@3946981.93@54@S@035.65972@0139.70406@iZV8jvlPzRhcJUTQiOuImQ@05@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381981.01@3946634.41@54@S@035.65651@0139.69620@tkeShLDl22a7rKGtIZUfbA@05@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382086.23@3947182.04@54@S@035.66145@0139.69728@p45FP6dsq_BpetQ8QMW-jQ@02@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382812.88@3946819.44@54@S@035.65827@0139.70536@3evynyDlXI0x-TDQ4ls5ng@10@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382716.84@3947061.10@54@S@035.66044@0139.70426@OOuBcz15x0oMdJC39Ck1Ng@06@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381910.48@3946327.83@54@S@035.65373@0139.69546@o0BeI1VBJ3WjMZFZ-OlY5w@03@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382028.98@3946141.77@54@S@035.65207@0139.69680@sqUdPbqw3Wk8P1xzO3jDmg@04@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381511.95@3947044.57@54@S@035.66015@0139.69096@8GqrkvSZ1pOd9pdNhlC5Ng@02@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382206.22@3947074.95@54@S@035.66050@0139.69862@1VDziDlMe29xfXxVZnABGQ@10@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382206.22@3947074.95@54@S@035.66050@0139.69862@1VDziDlMe29xfXxVZnABGQ@05@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382679.99@3946875.88@54@S@035.65877@0139.70388@M8eVs4U27Int-rfK_8VtDQ@01@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381613.03@3946945.93@54@S@035.65927@0139.69209@kBDAPBqyHqijQaoBQjAZ_w@05@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381645.99@3946530.70@54@S@035.65553@0139.69251@lTiQvQhQK84MZA4Ddr2fMA@05@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382381.03@3947265.45@54@S@035.66224@0139.70052@BqE0Zftkjt4GTaYhl_b2Jw@05@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382381.03@3947265.45@54@S@035.66224@0139.70052@BqE0Zftkjt4GTaYhl_b2Jw@10@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381871.66@3946581.50@54@S@035.65602@0139.69500@nRY4w8wq1xilc7Y-yrHTYQ@03@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382772.23@3946509.80@54@S@035.65548@0139.70495@m6tVQlKUVUtkL-Ue2JD7aw@00@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381650.24@3946551.28@54@S@035.65572@0139.69256@HzTO-8RyeBVhsDZzmZIgZg@01@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381552.26@3946644.88@54@S@035.65655@0139.69146@GLbxCW_SLkdLpKKasOYFJg@01@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382153.22@3947030.84@54@S@035.66010@0139.69804@-tti2iyV9VUQd5t7myBc9g@04@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382199.57@3947194.52@54@S@035.66158@0139.69853@9VZ59dL5MWZRQd-5mcU5iQ@08@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382153.22@3947030.84@54@S@035.66010@0139.69804@-tti2iyV9VUQd5t7myBc9g@11@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382871.49@3946408.64@54@S@035.65458@0139.70606@S46FmAJkewTtZmxrDeRLhw@01@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382179.32@3946513.30@54@S@035.65544@0139.69840@SmqeMWFujqInjaCRJFCRxg@07@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381987.06@3946756.14@54@S@035.65760@0139.69625@kr487aFQ1X6b3xHp9LFg9g@06@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381974.57@3946558.50@54@S@035.65582@0139.69614@pXEIoYcVk3vKKfF_hf9ZAA@01@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382321.13@3946583.31@54@S@035.65609@0139.69996@3xbCHLh-khWEBcL2btnPig@04@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381944.49@3946550.03@54@S@035.65574@0139.69581@cZtfT1eaII-GQquj-qFxEQ@00@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381766.40@3946291.91@54@S@035.65339@0139.69388@SiwpK9ueD8dmnFEG1QewnQ@08@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382133.81@3946728.12@54@S@035.65737@0139.69787@JLaVAmfUdqmTj6f1e78hCQ@08@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382075.19@3947066.26@54@S@035.66041@0139.69717@EFfwv7hLhEkBQj7KCncimQ@00@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382123.31@3946946.37@54@S@035.65934@0139.69772@jcG3Sde4bsRPQ-_lTSJwQw@07@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382454.97@3946235.64@54@S@035.65297@0139.70149@kQZFp7L1AeAGNH64x2Sfzw@01@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382463.22@3946366.44@54@S@035.65415@0139.70156@3GLsOWvAjvDU5h2fwm7vPg@03@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381903.58@3946319.27@54@S@035.65366@0139.69539@XR9VkPM9fTW92PpP0ZSRpA@05@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381980.74@3946737.03@54@S@035.65743@0139.69618@yI0HCxlVf1As9u2u-SbJQg@10@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381980.74@3946737.03@54@S@035.65743@0139.69618@yI0HCxlVf1As9u2u-SbJQg@05@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382532.24@3947260.34@54@S@035.66221@0139.70219@2Nodra1ngiMgomAO9jD8iQ@03@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381860.52@3946588.20@54@S@035.65608@0139.69487@a0q5k7FowcpLVCPrNFj4FA@00@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382769.31@3946631.86@54@S@035.65658@0139.70490@GRQsKgQuYwBMX672T_f9_A@00@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382417.11@3946775.63@54@S@035.65783@0139.70099@Vazlck-rZQg6Q7dS5ILhjQ@00@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382856.68@3947016.77@54@S@035.66006@0139.70581@spblJcFD6GKjwVbBjlryRg@11@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381967.08@3946826.63@54@S@035.65824@0139.69601@KHCzZ-wMDxJwsSmr_kWldg@03@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382328.30@3946701.48@54@S@035.65715@0139.70002@aVEVvPoxAUfofi83kkSSUA@05@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382690.85@3947458.49@54@S@035.66402@0139.70392@gTmrQ3BF4M5ucOxLowudoQ@05@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382564.92@3946162.86@54@S@035.65233@0139.70271@q183WY9dbQoGlA6R3YAoVA@05@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382104.20@3947266.89@54@S@035.66222@0139.69746@eTXD_5UzQYTpapsf0JEX_A@08@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382788.46@3946615.08@54@S@035.65643@0139.70512@BgBIh3wtujRmlMhCJnAqPA@03@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382769.30@3946288.07@54@S@035.65348@0139.70495@XihNzBQDSyEdz1QdjCQEnQ@10@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382304.46@3946986.90@54@S@035.65972@0139.69972@hpwdaZZ1cIFr15zsoR3XtA@11@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382590.35@3946841.01@54@S@035.65844@0139.70290@z64IVtDyNK8d64RKNbqmTA@02@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382117.68@3946145.59@54@S@035.65212@0139.69778@vHm9ivOalfOBLL9ezG6h-w@03@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381647.41@3947256.87@54@S@035.66208@0139.69242@1jHuqGlbJR7Q6XH-_45m7w@00@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381643.77@3946792.76@54@S@035.65789@0139.69245@gbEmHXl8EDWtnC5Kdxbd7g@10@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381992.96@3946675.74@54@S@035.65688@0139.69632@WhUYVASNWbEWKk-1Al-MKQ@00@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382769.30@3946288.07@54@S@035.65348@0139.70495@XihNzBQDSyEdz1QdjCQEnQ@05@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381841.47@3946319.65@54@S@035.65365@0139.69470@Z-M8yFP1gdvwk-QInIRj3g@00@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381968.06@3946401.95@54@S@035.65441@0139.69609@1znJzFkbmkdrKBaRfEmp0w@03@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382454.99@3946586.87@54@S@035.65613@0139.70144@-1T3GIFvle-3OQUpjFUDDQ@01@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382118.23@3946419.48@54@S@035.65458@0139.69774@MkZN4hiV1iwMJ1Ny3v7rUg@01@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381999.50@3947475.18@54@S@035.66409@0139.69628@0vre1Ziw5PkZ0-UwyXNoIQ@05@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382056.78@3947282.06@54@S@035.66235@0139.69694@Aw9Sa0kRxZnH0dXlzs63kA@03@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382181.90@3947186.77@54@S@035.66151@0139.69833@novrKKcMRL1uUNm_CJVI1w@09@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381569.47@3946604.71@54@S@035.65619@0139.69166@wXhedYC5bmgy6ZL_vnrr1g@02@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381497.27@3946635.85@54@S@035.65646@0139.69085@cag0aUGGJjz7s5w9rRncBg@02@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382186.26@3947119.15@54@S@035.66090@0139.69839@Nz695jPIKID_93oazGC4Jw@04@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382007.97@3946154.81@54@S@035.65219@0139.69656@NLs9fZ5h6jbhvHgWjDgI5Q@08@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381866.51@3947284.58@54@S@035.66235@0139.69484@VNBkHLnVdP-LDXkYhe7kKg@01@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382883.96@3946819.72@54@S@035.65828@0139.70614@N63p4i_5g53IsN0p9cTScg@04@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381822.90@3946468.88@54@S@035.65499@0139.69447@EoVzbXou4art2wAslVsFtg@10@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381642.15@3946242.20@54@S@035.65293@0139.69251@47kzVsm7p0a6DbAxL61MYg@07@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382387.64@3946669.74@54@S@035.65687@0139.70068@mghz1rGDuz1dws6jMccKpg@04@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381912.06@3946889.82@54@S@035.65880@0139.69540@CzuKf7BSTd0cNIaI_KsvZg@05@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382363.58@3947369.63@54@S@035.66318@0139.70031@fOIjG3tCrvQl9qNDgAQgxg@09@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382680.83@3946451.54@54@S@035.65494@0139.70395@Ebf4I3BrnVevo3K35sly2A@02@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381974.59@3946410.29@54@S@035.65448@0139.69616@hfMTERMqyMTvtE2iOtOYNA@00@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382406.04@3947280.98@54@S@035.66238@0139.70080@k1dHH95avLEz2Pnu97bQwg@04@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382406.04@3947280.98@54@S@035.66238@0139.70080@k1dHH95avLEz2Pnu97bQwg@11@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382297.57@3946773.55@54@S@035.65780@0139.69967@8gM7wm6X2kqxg_Kvn1J5Hg@06@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381875.10@3947004.13@54@S@035.65983@0139.69497@J1SGMOxKpKQZZnUQOV0HGA@06@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382338.14@3947006.75@54@S@035.65990@0139.70009@AJjLGeBSdqN0DVVpvxxpjQ@09@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382080.47@3946665.04@54@S@035.65679@0139.69729@BS7u_29m-xr1hzqMj1ZSnQ@09@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381468.33@3946706.02@54@S@035.65709@0139.69052@yAbI3BKq8xpImGS9_MUUQQ@04@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381816.28@3946679.20@54@S@035.65689@0139.69437@W1cCDckFS_pw8sfGuCFNsg@07@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382707.86@3946984.01@54@S@035.65974@0139.70417@sKVSnbW_Y3ijmyzMyo6QMQ@06@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382337.49@3946574.89@54@S@035.65601@0139.70014@v6sOiS9UpX6bdiUDCy5OPA@04@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382202.60@3947067.79@54@S@035.66044@0139.69858@McHRMo4gXRxkpn6RKBb9MA@04@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382045.33@3946521.07@54@S@035.65549@0139.69692@ype7rX_z9BB7f_d28ZAuew@11@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382077.58@3946699.91@54@S@035.65711@0139.69725@fHAB-6QQ-f8nnhU6IK1iGg@04@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382353.81@3946980.14@54@S@035.65967@0139.70026@4BpIqzq3wqT-e5c4vBSLyA@01@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382077.58@3946699.91@54@S@035.65711@0139.69725@fHAB-6QQ-f8nnhU6IK1iGg@11@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382686.48@3947078.92@54@S@035.66060@0139.70392@eq6hjs60_UedU7O6AeDsAg@03@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382389.64@3947006.30@54@S@035.65991@0139.70066@WL6aDhBWcdqYHfq70f9SmQ@04@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381472.03@3946576.28@54@S@035.65592@0139.69058@W2_p7a52WwFekjH0Gpj3Rw@04@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382075.10@3946581.02@54@S@035.65604@0139.69724@4Mlea127J-F9dNbebe9gjQ@11@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382297.71@3946968.91@54@S@035.65956@0139.69965@ltiIgs9gxp4RoL3HcRkvww@07@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381668.42@3946243.41@54@S@035.65294@0139.69280@z-hVVEvfrl4yiASmNGGMCw@10@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381658.51@3947240.31@54@S@035.66193@0139.69255@G2M2a0uxU0nTGpnEA4qSrg@01@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382085.26@3946883.19@54@S@035.65876@0139.69731@cvc88jQIBMNhNHq70ZHB0A@02@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382717.95@3946396.91@54@S@035.65445@0139.70437@M8GgUYiqcvyQx0PIAbFdZQ@11@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381946.91@3946923.30@54@S@035.65911@0139.69578@6AIDO-9U4GvaiwY9M3gjCQ@03@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382285.81@3946343.05@54@S@035.65392@0139.69961@tULf4yLe29jVVCeYTVg9PA@10@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382552.14@3947052.74@54@S@035.66035@0139.70244@bfvQvxMsp5Hvj4uObQzTsg@09@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382059.26@3946397.30@54@S@035.65438@0139.69710@fQB0rM2oSeFHMIqIULSHug@02@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382556.80@3947022.28@54@S@035.66007@0139.70250@FZM0JxITULUAAAGu5ucsRg@03@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381783.12@3946739.21@54@S@035.65743@0139.69400@jt97dw4TnWHYJ7BIT0BQgQ@01@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382414.96@3946373.84@54@S@035.65421@0139.70103@aypIPsmq5MGDrNfzgKUpbg@10@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382043.91@3946584.88@54@S@035.65607@0139.69690@serz3TjSvXqzpVdBzohfXg@05@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382723.49@3946995.67@54@S@035.65985@0139.70434@cN0g84ptmZ1In0F6tggVvQ@11@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381428.79@3946531.70@54@S@035.65551@0139.69011@1VG-mymObrO9FUW5IPddGA@02@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382588.50@3947215.11@54@S@035.66181@0139.70282@Hx97CMDRo_308MzjsvIq9Q@03@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381453.67@3946584.51@54@S@035.65599@0139.69038@tlf4tTBdExNjweG9OMManA@04@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382281.51@3946729.72@54@S@035.65740@0139.69950@H1W5t6D3UhAnLAFO-xvnpg@02@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382908.83@3946494.46@54@S@035.65535@0139.70646@MeBwXd0J14RGljA3MCqO1Q@03@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382750.49@3946729.18@54@S@035.65745@0139.70468@7SqS0c_xzHxBLlthrJQhAQ@02@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381929.20@3946816.92@54@S@035.65814@0139.69560@zqporhBjfRON5a2qwlmbAQ@04@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382599.63@3946460.15@54@S@035.65501@0139.70305@L_OEMHHlrq5iF8R9UlmPVA@11@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382740.19@3946998.89@54@S@035.65988@0139.70453@2x44NbC98ncxbGngrV6hEQ@09@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382119.95@3947027.73@54@S@035.66007@0139.69767@W0MpLFNDR-PqSdrff0_nIA@05@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382451.25@3947468.20@54@S@035.66408@0139.70127@Orgr26H5q-1ceVSgWVWa3g@06@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382276.24@3946981.39@54@S@035.65967@0139.69941@EX9qHY1MoLRsjYjXHmbfZw@04@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382276.24@3946981.39@54@S@035.65967@0139.69941@EX9qHY1MoLRsjYjXHmbfZw@11@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382039.98@3947251.10@54@S@035.66207@0139.69676@ESYS7q6RmD1IcyVvYZhkFQ@05@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381989.69@3946503.83@54@S@035.65533@0139.69631@yxXURhGqpPJzqKNOUbhfIA@08@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382313.30@3947340.12@54@S@035.66291@0139.69976@HH-T7mIVZNxCYJsBhStwPA@10@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382261.32@3946956.07@54@S@035.65944@0139.69925@WFNDbrV8IEOEOnqc88VeVg@00@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381925.21@3947001.02@54@S@035.65980@0139.69553@Iq7PetdrFZonFEaIOVMpyQ@02@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381524.77@3946729.45@54@S@035.65731@0139.69114@KQxx1PUE2NUdUCpS9DXyMg@09@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382410.20@3946657.13@54@S@035.65676@0139.70093@AeqVSzwaGIORFGEJHLK1YA@05@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382410.20@3946657.13@54@S@035.65676@0139.70093@AeqVSzwaGIORFGEJHLK1YA@10@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382121.84@3946910.44@54@S@035.65901@0139.69771@xNhmWn3-zIgFBbwHGt2ndg@09@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382252.21@3946992.69@54@S@035.65977@0139.69914@bf0X44qnln_EQx8yy9Womw@07@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381852.02@3946507.21@54@S@035.65534@0139.69479@VAlUgPm7IJJ-qS8uCBOmVA@04@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381714.64@3946647.93@54@S@035.65660@0139.69325@eyRuUFPGFUvqbaHRnBRHgQ@00@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381834.59@3946510.66@54@S@035.65537@0139.69460@rpWRnBnfGO-aZ7_bZsLU4g@03@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382241.10@3947390.88@54@S@035.66336@0139.69896@1D7S7W9Pv9N89KAIJxTzig@03@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382054.03@3946466.82@54@S@035.65500@0139.69703@7o2ZQosOQQA7scU_Q2TRMA@05@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381850.25@3947334.83@54@S@035.66280@0139.69465@pHBE5LiMRKydtLPUkxw_wQ@09@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382572.94@3947126.79@54@S@035.66101@0139.70266@hbavI0S3qaZC81cBGH4pUg@00@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381702.67@3947252.48@54@S@035.66204@0139.69303@A7QYlGxkg7S6XDwUoY7zug@07@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381915.47@3946532.89@54@S@035.65558@0139.69549@i-S6kCMLz2GuK2BWFribKg@07@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382751.31@3946784.53@54@S@035.65795@0139.70468@furxbbh_HLBy7oYBKc7Tqg@08@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382534.53@3947111.55@54@S@035.66087@0139.70224@SuQw7bMbyIC-qYXqEPtxgQ@09@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382321.89@3946791.53@54@S@035.65796@0139.69994@zRToW_7ikzIAAAAGOqCjOQ@04@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382709.90@3946273.77@54@S@035.65334@0139.70430@u2BP8mmQHT6D3Y-o1OvzJg@06@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382347.76@3946960.81@54@S@035.65949@0139.70020@AEHb_MlokX2ItEOKQ9UATw@07@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381738.75@3947018.14@54@S@035.65994@0139.69346@8m-Qe_tP84Al4p6SRQrmTA@06@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382127.51@3946682.61@54@S@035.65696@0139.69781@pdBcdsJIZ4e4cruKQP89AQ@03@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382388.54@3946723.98@54@S@035.65736@0139.70068@YzsU657Vp0BjZM63HGIOZg@01@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381733.88@3946392.41@54@S@035.65429@0139.69350@Ys_qRnbg-k38h3SLnxasPw@09@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382788.91@3947452.87@54@S@035.66398@0139.70500@3BgAnvLl2QQLPBt2A2Sirw@04@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382901.50@3946831.92@54@S@035.65840@0139.70633@izjZldVzt9WUqalp1VIrXw@05@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382152.64@3947041.72@54@S@035.66020@0139.69803@YZhZqY_Bitc1KqTPXBXuLQ@04@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381989.89@3946348.41@54@S@035.65393@0139.69634@65-LXaTJh2VoZ2rASN4gMQ@04@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382183.85@3947122.29@54@S@035.66093@0139.69837@rDJriQslG8HO-I8c9P8bOg@04@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382827.81@3947011.05@54@S@035.66000@0139.70549@-EnjrMnXcRncXpo_BwpEgA@02@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382743.09@3946216.09@54@S@035.65283@0139.70467@WF_rjLeAkc-s1jAbsy0Y8w@00@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382008.75@3946575.36@54@S@035.65598@0139.69651@LkwK-5ws_Em-7zDsoX09qA@09@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381703.44@3946548.35@54@S@035.65570@0139.69314@FmPcboxUI6I12rkP-4ZHEg@04@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381846.76@3946983.54@54@S@035.65964@0139.69466@Z3nOVZbJuBiCh8eEIBE7qw@11@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382716.15@3947482.34@54@S@035.66424@0139.70419@CYkBHZmh1-86VAURAVsj_w@03@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382680.08@3946587.33@54@S@035.65616@0139.70392@lrgikOzNPSa6tsNeOYB3lg@01@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382894.65@3947480.21@54@S@035.66424@0139.70616@PSNDprLl-3fYuGdb6oL-jA@02@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381957.87@3947203.71@54@S@035.66163@0139.69586@H9bjLhwMagyfjL3se_Aj1A@06@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382054.86@3946918.76@54@S@035.65908@0139.69697@NKFWpKeH6rNGEeSaeERAYQ@04@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382054.86@3946918.76@54@S@035.65908@0139.69697@NKFWpKeH6rNGEeSaeERAYQ@11@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381962.04@3946501.43@54@S@035.65531@0139.69601@PEHqMSrqH4A0rXUijfCVXQ@03@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382783.36@3947114.03@54@S@035.66092@0139.70499@VtwjujgJOgA2ayy9XTJrLQ@05@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382721.84@3947144.80@54@S@035.66120@0139.70430@STR4asqjVLn4La3pWksyKg@00@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382531.59@3947285.98@54@S@035.66245@0139.70218@oqk6fjf7fB9e_2lPvyIISQ@02@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382180.12@3947018.39@54@S@035.65999@0139.69834@yD2cIXOqQtbDHBrggvE6zw@02@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381448.01@3946247.89@54@S@035.65296@0139.69037@3uZNAXk_X_aIP5XRMUEcHw@11@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381696.65@3946500.18@54@S@035.65526@0139.69308@3bPdvI-8AvLWIBalb9q3tA@08@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382400.87@3946732.13@54@S@035.65744@0139.70082@JSpAxB2SDS8TXTtLMHahMA@00@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382276.18@3947031.87@54@S@035.66012@0139.69940@wwvbqR45NqbiJEp3MRNXKQ@03@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381684.11@3947279.68@54@S@035.66229@0139.69282@mltFJdQookWrVBSkcFzISA@00@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381827.43@3946694.03@54@S@035.65703@0139.69449@tl12gPU4iZYBF4yY0wOkGg@01@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382879.40@3946831.10@54@S@035.65839@0139.70609@VdIh_u06pOfUFgiRX_zesQ@06@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382110.13@3946901.72@54@S@035.65893@0139.69758@rLCsutONuMlmuWF5nzJW4w@07@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382193.39@3947049.72@54@S@035.66028@0139.69848@YL6F9HswJUqYL88g0WH_KA@02@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382416.16@3947060.53@54@S@035.66040@0139.70094@hcNvYOARxiZsCr9ope_kng@09@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382223.51@3946944.59@54@S@035.65933@0139.69883@ohcQNQpAoa037FyqigTBIQ@02@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382429.99@3946469.05@54@S@035.65507@0139.70118@6hBu1q1ewgftjfwezKu27A@05@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381985.73@3946553.70@54@S@035.65578@0139.69626@wN7Pjhpo6dkbVxbQOdIY-g@08@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382274.31@3947485.85@54@S@035.66422@0139.69931@mq5Qj7YZuB6TomVQSCzwuw@09@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382226.28@3947146.91@54@S@035.66116@0139.69883@yxXFxGUdh8t70TukR24gFg@08@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381830.48@3946691.77@54@S@035.65701@0139.69453@1OR5mGDHbY1pJJQGBGWQSg@01@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382137.93@3946916.00@54@S@035.65906@0139.69789@D-m94Gvi3Bj5eMWc6XUZWw@06@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382769.31@3946996.18@54@S@035.65986@0139.70485@T6ehcDeGBfLqgNhKARV4JQ@10@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382880.72@3946291.26@54@S@035.65352@0139.70618@nRD7qSJPn0M_0MO7rO2-YA@10@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382186.77@3946932.43@54@S@035.65922@0139.69843@MZh1xpDiXPjB2HxeXda9_w@00@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382018.86@3947235.85@54@S@035.66193@0139.69653@p6_1C21cKGr3PXl_MMnICQ@03@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382403.74@3947065.79@54@S@035.66044@0139.70080@xPZIUHVObHTtqmp1hpAvCQ@06@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382395.91@3946829.82@54@S@035.65832@0139.70075@OhMW0TaiWPDayCnvxJVXgA@09@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381492.80@3946803.09@54@S@035.65797@0139.69078@e2mkkuQk-OXklLpXXE2HcA@05@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382772.83@3947228.66@54@S@035.66196@0139.70486@QtCbUNL0LfQenlzXeMkQWA@03@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382758.72@3946886.71@54@S@035.65887@0139.70475@fVqlZxWT7gmCPBQv2HuaXA@00@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382760.40@3947047.88@54@S@035.66033@0139.70474@wDxbPtUGKEGFYdxxPQxx8w@06@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382729.70@3947026.77@54@S@035.66013@0139.70441@1tReAaLsuoGJsz57Wr7_BQ@00@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382711.80@3946548.64@54@S@035.65582@0139.70428@TPUcCbRvf-Mg6aXZJw3ELQ@02@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382808.09@3947087.75@54@S@035.66069@0139.70527@4pSydb5t3YYbID3rsxIESA@10@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382926.32@3946970.48@54@S@035.65965@0139.70659@xTU_BMvblHkg3N22CTJMuQ@07@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382268.75@3947277.80@54@S@035.66234@0139.69928@fmC0a06opNGNCnrTxtQJIw@07@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382143.60@3946551.05@54@S@035.65577@0139.69800@2PDG0obDCG5Oh7qK1YuhaQ@08@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382254.09@3947497.21@54@S@035.66432@0139.69909@ATUC4yICzSzTDdHlazeXag@08@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382260.75@3947398.17@54@S@035.66342@0139.69917@jL9RXw3UZmhB9qx7uTvTXg@01@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381801.68@3946657.54@54@S@035.65669@0139.69421@l2YJujycvA3wEc9SInCEiA@07@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381934.68@3947407.59@54@S@035.66347@0139.69557@LC6LIqLOvIIm80FFUIxJNw@01@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382499.88@3946742.69@54@S@035.65754@0139.70191@Ix2TyZxrH0KxDuBA9SF18Q@00@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382479.31@3946446.99@54@S@035.65488@0139.70173@hsXuJevzEKHhm-m94QHL8Q@00@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382853.99@3946688.77@54@S@035.65710@0139.70583@klbHf_XMeDrRRJl9F3Cdqg@05@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382212.43@3946299.20@54@S@035.65351@0139.69880@ksx2qMkXG-_PT6K1H9X1Fw@02@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382375.98@3947150.92@54@S@035.66121@0139.70048@Df7vmmgqRf7ZzpHVzaKLSg@08@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382216.19@3946740.79@54@S@035.65749@0139.69878@g1mlmey8dW3SRJNs9fJrmw@04@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382057.41@3946400.87@54@S@035.65441@0139.69707@e8-_g0k6qVIYrQgC0VU6qw@04@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382057.41@3946400.87@54@S@035.65441@0139.69707@e8-_g0k6qVIYrQgC0VU6qw@11@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382405.25@3947214.32@54@S@035.66178@0139.70080@F3z14tJ-HJuMU0f7f2CwVg@05@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381444.03@3946900.70@54@S@035.65884@0139.69023@X0DV0F-lURTMtFw0mrd44w@02@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382171.04@3947235.06@54@S@035.66194@0139.69821@KDzhPF6wIeoQnOWYPCWl-Q@11@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382347.39@3946569.98@54@S@035.65597@0139.70025@hUU4tzGHhURdsS5e26T5jQ@05@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382122.46@3947271.98@54@S@035.66227@0139.69767@7hbKPjbiay9_l3CKN9mDuA@00@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381955.40@3946703.64@54@S@035.65713@0139.69590@b5r2ri02-QD6yTl0zQPx7Q@01@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381768.66@3947435.87@54@S@035.66371@0139.69373@5gypvgFEpOr1ih-2vIFcNA@03@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381671.67@3947202.41@54@S@035.66159@0139.69270@h3CgULar4czWs0SGEzq_oQ@02@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381732.39@3946396.09@54@S@035.65433@0139.69349@OkvwOKtno4NkJ78jPYbUwg@07@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382046.46@3946572.08@54@S@035.65595@0139.69693@Sjg32b-LtWcUnTLDBaM2fw@00@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381987.77@3946427.09@54@S@035.65464@0139.69630@7Lr7ZlTPFoFHQ7m4iUvpVw@01@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382199.34@3947061.29@54@S@035.66038@0139.69855@8MGHUkoyPI6jkaWpYfAlJQ@09@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382083.66@3946953.44@54@S@035.65939@0139.69728@w7Mc2Had2LlwlR0xKt30xg@08@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382740.58@3946657.09@54@S@035.65680@0139.70458@ueDksWmN6-QPglE1aZOM8g@08@@@@@@@.jpg.jpg
# ...
#  inflated: tokyo-night-aug/test/database/@0381842.09@3946529.76@54@S@035.65555@0139.69468@4avqm0D1WjE5bDdwLwmxCw@06@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381999.88@3947012.79@54@S@035.65992@0139.69635@jFr009Fi3WjvkMI_-cRIkg@02@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382586.25@3947408.06@54@S@035.66355@0139.70277@onnPRLdIhHG4DZN3MP_gdw@03@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381758.16@3946537.08@54@S@035.65560@0139.69375@1KWkm1ME0ltEgleoI8GPyw@01@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382282.47@3946666.03@54@S@035.65683@0139.69952@R4X6-CVz4UNnleU1-D4plA@11@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381582.49@3946283.60@54@S@035.65330@0139.69185@JdBi9_-ycya0CEt63v7htA@04@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381767.89@3946431.34@54@S@035.65465@0139.69387@_sKKmZVG4jbHMNwFGkOs7w@10@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382543.67@3947309.56@54@S@035.66266@0139.70231@Ol0kOovCgSOFuw0DRzUUNA@03@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382876.36@3947019.40@54@S@035.66008@0139.70603@8XyEhm-K_4IrqjpmxOPgTQ@10@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382707.86@3946984.01@54@S@035.65974@0139.70417@sKVSnbW_Y3ijmyzMyo6QMQ@02@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382290.97@3946733.03@54@S@035.65743@0139.69961@8cpZOjuUOnIscalXCehwVQ@01@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382406.04@3947280.98@54@S@035.66238@0139.70080@k1dHH95avLEz2Pnu97bQwg@00@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381856.70@3947398.31@54@S@035.66338@0139.69471@LKT5S5gBUIJ4UiOsdDO14g@00@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382070.67@3946622.90@54@S@035.65641@0139.69719@GMb_i-Th7jW82VWyLr_ebw@07@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382450.16@3946591.48@54@S@035.65618@0139.70138@KUJTmcwMc6we3I0tq32aEQ@03@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382619.24@3947191.41@54@S@035.66160@0139.70316@FcMnth9uS4s2LHcKoPncvg@07@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382239.52@3946998.63@54@S@035.65982@0139.69900@mHRF5RqtnuGl3QGmhgU4GQ@02@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381903.31@3946333.36@54@S@035.65378@0139.69538@7cZVqoZNejBUBKJKKGWP8w@09@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382717.95@3946396.91@54@S@035.65445@0139.70437@M8GgUYiqcvyQx0PIAbFdZQ@00@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382837.98@3946243.35@54@S@035.65308@0139.70572@SPqH_J9B4iAvCV82wNCB2g@06@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381935.96@3947238.06@54@S@035.66194@0139.69561@jBHaUwproFwvlgYQW_J_jQ@06@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382516.65@3946682.79@54@S@035.65701@0139.70211@CO7qZsO2VCa_J08de1KGJQ@06@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382353.81@3946980.14@54@S@035.65967@0139.70026@4BpIqzq3wqT-e5c4vBSLyA@10@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382831.30@3946732.67@54@S@035.65749@0139.70557@BIwtSpUyQuSvGQWUYgu6Mg@03@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382389.64@3947006.30@54@S@035.65991@0139.70066@WL6aDhBWcdqYHfq70f9SmQ@00@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381621.50@3946452.70@54@S@035.65482@0139.69225@0x5om2XHeMjHe-O08_gNqw@02@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0381469.80@3946857.65@54@S@035.65846@0139.69052@Gy3f5g6YR7aqE6FubIcCAQ@09@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/database/@0382112.74@3947269.33@54@S@035.66224@0139.69756@6eEUjG2UEHhu1P6l6rvCNg@09@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382199.75@3947070.05@54@S@035.66046@0139.69855@00093.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0381919.30@3947017.64@54@S@035.65995@0139.69546@00063.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382757.84@3946728.31@54@S@035.65745@0139.70476@00228.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382757.84@3946728.31@54@S@035.65745@0139.70476@00231.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382867.31@3946708.57@54@S@035.65728@0139.70598@00237.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0381919.30@3947017.64@54@S@035.65995@0139.69546@00060.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0381807.40@3946274.62@54@S@035.65324@0139.69433@00396.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382222.68@3947099.03@54@S@035.66072@0139.69880@00186.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382576.69@3946167.48@54@S@035.65237@0139.70284@00276.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382291.77@3947093.24@54@S@035.66068@0139.69956@00180.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382199.75@3947070.05@54@S@035.66046@0139.69855@00096.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0381548.01@3946636.62@54@S@035.65647@0139.69141@00738.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382168.51@3947083.00@54@S@035.66057@0139.69820@00198.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382794.06@3946461.03@54@S@035.65504@0139.70520@00267.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382351.18@3947183.09@54@S@035.66150@0139.70021@00168.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382757.84@3946728.31@54@S@035.65745@0139.70476@00234.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0381807.40@3946274.62@54@S@035.65324@0139.69433@00390.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382351.18@3947183.09@54@S@035.66150@0139.70021@00171.jpg@@@@@@@@.jpg.jpg
#  inflated: __MACOSX/tokyo-night-aug/test/queries/._@0382351.18@3947183.09@54@S@035.66150@0139.70021@00171.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382291.77@3947093.24@54@S@035.66068@0139.69956@00174.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0381807.40@3946274.62@54@S@035.65324@0139.69433@00393.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382291.77@3947093.24@54@S@035.66068@0139.69956@00177.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382093.39@3947255.39@54@S@035.66212@0139.69735@00219.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382576.69@3946167.48@54@S@035.65237@0139.70284@00273.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382794.06@3946461.03@54@S@035.65504@0139.70520@00264.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382222.68@3947099.03@54@S@035.66072@0139.69880@00183.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382283.57@3947273.62@54@S@035.66230@0139.69945@00159.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382794.06@3946461.03@54@S@035.65504@0139.70520@00270.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0381994.26@3946757.71@54@S@035.65762@0139.69633@00036.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382216.21@3946548.54@54@S@035.65576@0139.69881@00441.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382125.73@3947209.48@54@S@035.66171@0139.69771@00204.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382199.75@3947070.05@54@S@035.66046@0139.69855@00099.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382154.08@3946929.77@54@S@035.65919@0139.69807@00021.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0381909.70@3946894.18@54@S@035.65884@0139.69537@00054.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0381888.16@3946594.82@54@S@035.65614@0139.69518@00039.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382351.18@3947183.09@54@S@035.66150@0139.70021@00165.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382283.57@3947273.62@54@S@035.66230@0139.69945@00156.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382414.21@3947122.79@54@S@035.66096@0139.70091@00135.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382154.08@3946929.77@54@S@035.65919@0139.69807@00023.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382168.51@3947083.00@54@S@035.66057@0139.69820@00195.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0381548.01@3946636.62@54@S@035.65647@0139.69141@00735.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382125.73@3947209.48@54@S@035.66171@0139.69771@00207.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382125.73@3947209.48@54@S@035.66171@0139.69771@00201.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382414.21@3947122.79@54@S@035.66096@0139.70091@00132.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382168.51@3947083.00@54@S@035.66057@0139.69820@00192.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0381994.26@3946757.71@54@S@035.65762@0139.69633@00032.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0381548.01@3946636.62@54@S@035.65647@0139.69141@00732.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0381909.70@3946894.18@54@S@035.65884@0139.69537@00048.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382063.64@3946397.80@54@S@035.65438@0139.69714@00417.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382576.69@3946167.48@54@S@035.65237@0139.70284@00279.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382222.68@3947099.03@54@S@035.66072@0139.69880@00189.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0381909.70@3946894.18@54@S@035.65884@0139.69537@00051.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382414.21@3947122.79@54@S@035.66096@0139.70091@00129.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0381994.26@3946757.71@54@S@035.65762@0139.69633@00030.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382154.08@3946929.77@54@S@035.65919@0139.69807@00026.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382283.57@3947273.62@54@S@035.66230@0139.69945@00162.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0381888.16@3946594.82@54@S@035.65614@0139.69518@00045.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0381904.46@3946329.36@54@S@035.65375@0139.69540@00399.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382867.31@3946708.57@54@S@035.65728@0139.70598@00240.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382093.39@3947255.39@54@S@035.66212@0139.69735@00222.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0381996.23@3946442.07@54@S@035.65477@0139.69639@00411.jpg@@@@@@@@.jpg.jpg
#  inflated: __MACOSX/tokyo-night-aug/test/queries/._@0381996.23@3946442.07@54@S@035.65477@0139.69639@00411.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0381523.71@3946790.15@54@S@035.65786@0139.69112@00693.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0381996.23@3946442.07@54@S@035.65477@0139.69639@00408.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382284.78@3946975.18@54@S@035.65961@0139.69950@00012.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382309.87@3947030.54@54@S@035.66012@0139.69977@00111.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0381523.71@3946790.15@54@S@035.65786@0139.69112@00690.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382392.56@3947053.74@54@S@035.66034@0139.70068@00126.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382867.31@3946708.57@54@S@035.65728@0139.70598@00243.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382436.16@3946523.67@54@S@035.65556@0139.70124@00450.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382147.66@3946452.27@54@S@035.65488@0139.69806@00426.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382063.64@3946397.80@54@S@035.65438@0139.69714@00423.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382284.78@3946975.18@54@S@035.65961@0139.69950@00015.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382138.93@3947132.54@54@S@035.66102@0139.69787@00087.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382392.56@3947053.74@54@S@035.66034@0139.70068@00120.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382309.87@3947030.54@54@S@035.66012@0139.69977@00117.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382357.86@3947263.87@54@S@035.66223@0139.70027@00147.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0381996.23@3946442.07@54@S@035.65477@0139.69639@00414.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0381888.16@3946594.82@54@S@035.65614@0139.69518@00041.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382309.87@3947030.54@54@S@035.66012@0139.69977@00114.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382216.21@3946548.54@54@S@035.65576@0139.69881@00438.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382093.39@3947255.39@54@S@035.66212@0139.69735@00225.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382257.19@3947045.66@54@S@035.66025@0139.69919@00108.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382138.93@3947132.54@54@S@035.66102@0139.69787@00084.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382392.56@3947053.74@54@S@035.66034@0139.70068@00123.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382063.64@3946397.80@54@S@035.65438@0139.69714@00420.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0381904.46@3946329.36@54@S@035.65375@0139.69540@00402.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382076.70@3947171.52@54@S@035.66136@0139.69718@00216.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382257.19@3947045.66@54@S@035.66025@0139.69919@00105.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382138.93@3947132.54@54@S@035.66102@0139.69787@00090.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382216.21@3946548.54@54@S@035.65576@0139.69881@00435.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0381654.35@3946435.74@54@S@035.65468@0139.69262@00384.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382357.86@3947263.87@54@S@035.66223@0139.70027@00150.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0381654.35@3946435.74@54@S@035.65468@0139.69262@00387.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382357.86@3947263.87@54@S@035.66223@0139.70027@00153.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0381919.30@3947017.64@54@S@035.65995@0139.69546@00056.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382284.78@3946975.18@54@S@035.65961@0139.69950@00018.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382076.70@3947171.52@54@S@035.66136@0139.69718@00213.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382147.66@3946452.27@54@S@035.65488@0139.69806@00432.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382436.16@3946523.67@54@S@035.65556@0139.70124@00444.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0381654.35@3946435.74@54@S@035.65468@0139.69262@00381.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0381904.46@3946329.36@54@S@035.65375@0139.69540@00405.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0381523.71@3946790.15@54@S@035.65786@0139.69112@00687.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382147.66@3946452.27@54@S@035.65488@0139.69806@00429.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382257.19@3947045.66@54@S@035.66025@0139.69919@00102.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382436.16@3946523.67@54@S@035.65556@0139.70124@00447.jpg@@@@@@@@.jpg.jpg
#  inflated: tokyo-night-aug/test/queries/@0382076.70@3947171.52@54@S@035.66136@0139.69718@00210.jpg@@@@@@@@.jpg.jpg

# %% [markdown]
# # Download Code

# %% [markdown]
# Clone of original repo of CosPlace and our code

# %%
# download code of CosPlace
# !git clone "https://github.com/gmberton/CosPlace" 
#!rm -r "/content/CosPlace"

# download our code
# !git clone --single-branch --branch "gab" "https://github.com/gab-palmeri/aml-geolocalization.git"
# !mv "/content/aml-geolocalization/" "/content/Team"
#!rm -r "/content/aml-geolocalization"
# Out:
# fatal: destination path 'CosPlace' already exists and is not an empty directory.
# Cloning into 'aml-geolocalization'...
# remote: Enumerating objects: 390, done.
# remote: Counting objects: 100% (89/89), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 390 (delta 48), reused 67 (delta 35), pack-reused 301
# Receiving objects: 100% (390/390), 2.63 MiB | 25.36 MiB/s, done.
# Resolving deltas: 100% (174/174), done.

# %% [markdown]
# # Import Code

# %%
import os
import sys
import torch
import logging
import multiprocessing
import numpy as np
import torchvision.transforms as T
from tqdm import tqdm
from datetime import datetime

sys.path.append("/content/CosPlace/")
sys.path.append("/content/Team/")
import CosPlace
from CosPlace import *

torch.backends.cudnn.benchmark = True  # Provides a speedup

# %% [markdown]
# This class let us to access to dictionary keys like `dict.key` instead of `dict["key"]`

# %%
class dotdict(dict):
    """dot.notation access to dictionary attributes"""
    __getattr__ = dict.get
    __setattr__ = dict.__setitem__
    __delattr__ = dict.__delitem__

# %% [markdown]
# Drive related functions to save and load training checkpoints

# %%
import os
from google.colab import drive

drive.mount('/content/drive')

def drive_save_checkpoint(output_folder, time):
    drive_folder = "/content/drive/MyDrive/project6/"
    if not os.path.exists(drive_folder):
        # !mkdir "/content/drive/MyDrive/project6/"
    # !zip -r "/content/drive/MyDrive/project6/{time}.zip" "/content/{output_folder}"

def drive_load_checkpoint(input_folder, time):
    drive_folder = "/content/drive/MyDrive/project6/"
    # !jar xvf "/content/drive/MyDrive/project6/{time}.zip"

def drive_tester(output_folder):
    drive_folder = "/content/drive/MyDrive/project6/"
    if not os.path.exists(drive_folder):
        # !mkdir "/content/drive/MyDrive/project6/"
    # !touch "/content/drive/MyDrive/project6/test"

    if os.path.exists("/content/drive/MyDrive/project6/test"):
        logging.info("Drive saving works")
    else:
        logging.info("WARNING: Drive saving does not work")

# use this function when content on drive are not updated
def drive_refresh():
  drive.flush_and_unmount()
  drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Parameters

# %% [markdown]
# Original code provides two main executable files: `train.py` and `eval.py`. We want to reproduce the same behaviour of these two files so these are the parameters passed via terminal. They will be put in a dict called `args` to simply reuse code inside ex files

# %% [markdown]
# ## Setup parameters

# %%
# CosPlace Groups parameters
COS_M = 10
ALPHA = 30
COS_N = 5
COS_L = 2
GROUPS_NUM = 1
MIN_IMAGES_PER_CLASS = 10
# Model parameters
BACKBONE = "efficientnet_v2_s"   
# ["resnet18", "efficientnet_b2", "efficientnet_v2_s", "mobilenet_v3_small", "mobilenet_v3_large",
# ["convnext_tiny", "swin_tiny", "cct384"]
FC_OUTPUT_DIM = 512     # Output dimension of final fully connected layer
PRETRAIN = "imagenet"   # ["imagenet", "places", "gldv2"]
# Training parameters
AUGMENTATION_DEVICE = "cuda"    # ["cuda", "cpu"]
USE_AMP_16 = AUGMENTATION_DEVICE == "cuda"       # use Automatic Mixed Precision
BATCH_SIZE = 32
EPOCHS_NUM = 3
ITERATIONS_PER_EPOCH = 10_000
LR = 0.00001                    # Learning rate  
CLASSIFIERS_LR = 0.01
# Data augmentation
BRIGHTNESS = 0.7
CONTRAST = 0.7
SATURATION = 0.7
HUE = 0.5
RANDOM_RESIZED_CROP = 0.5
# Validation / test parameters
INFER_BATCH_SIZE = 16           # Batch size for inference (validating and testing)
POSITIVE_DIST_THRESHOLD = 25    # distance in meters for a prediction to be considered a positive
# Resume parameters
RESUME_TRAIN = None     # path to checkpoint to resume, e.g. logs/.../last_checkpoint.pth
RESUME_MODEL = None     # Path to model to resume training from
# Other parameters
DEVICE = "cuda"                     # ["cuda", "cpu"]
SEED = 0
NUM_WORKERS = 8
DATASET_FOLDER = "/content/small"   # path of the folder with train/val sets
SAVEDIR = BACKBONE + "_" + PRETRAIN


if not os.path.exists(DATASET_FOLDER):
    raise FileNotFoundError(f"Dataset folder {DATASET_FOLDER} not found")

train_set_folder = os.path.join(DATASET_FOLDER, "train")

if not os.path.exists(train_set_folder):
    raise FileNotFoundError(f"Train set folder {train_set_folder} not found")

val_set_folder = os.path.join(DATASET_FOLDER, "val")

if not os.path.exists(val_set_folder):
    raise FileNotFoundError(f"Validation set folder {val_set_folder} not found")

if BACKBONE != "resnet18" and PRETRAIN != "imagenet":
    raise ValueError("Only resnet18 can be pretrained on other datasets than ImageNet")

# dictionary for the parameters
args = {
    'M': COS_M, 'alpha': ALPHA, 'N': COS_N, 'L': COS_L, 'groups_num': GROUPS_NUM,
    'min_images_per_class': MIN_IMAGES_PER_CLASS, 'backbone': BACKBONE, "pretrain": PRETRAIN,
    'fc_output_dim': FC_OUTPUT_DIM, 'use_amp16': USE_AMP_16,
    'augmentation_device': AUGMENTATION_DEVICE, 'batch_size': BATCH_SIZE,
    'epochs_num': EPOCHS_NUM, 'iterations_per_epoch': ITERATIONS_PER_EPOCH,
    'lr': LR, 'classifiers_lr': CLASSIFIERS_LR, 'brightness': BRIGHTNESS,
    'contrast': CONTRAST, 'hue': HUE, 'saturation': SATURATION,
    'random_resized_crop': RANDOM_RESIZED_CROP, 'infer_batch_size': INFER_BATCH_SIZE,
    'positive_dist_threshold': POSITIVE_DIST_THRESHOLD, 'resume_train': RESUME_TRAIN,
    'resume_model': RESUME_MODEL, 'device': DEVICE, 'seed': SEED,
    'num_workers': NUM_WORKERS, 'dataset_folder': DATASET_FOLDER, 'save_dir': SAVEDIR,
    'val_set_folder': val_set_folder, 'train_set_folder': train_set_folder,
}

# this helps to reuse the code from the original CosPlace
args = dotdict(args)

# %%
saveDirLocal = SAVEDIR

# %% [markdown]
# # Setup logging

# %%
from CosPlace import commons

start_time = datetime.now()
output_folder = f"logs/{args.save_dir}/{start_time.strftime('%Y-%m-%d_%H-%M-%S')}"
commons.make_deterministic(args.seed)
commons.setup_logging(output_folder, console=None)
logging.info(" ".join(sys.argv))
logging.info(f"Arguments: {args}")
logging.info(f"The outputs are being saved in {output_folder}")
# Out:
# INFO:root:/usr/local/lib/python3.8/dist-packages/ipykernel_launcher.py -f /root/.local/share/jupyter/runtime/kernel-ad7ef816-75d6-4bd6-8bf1-a45ed91e1bca.json
# INFO:root:Arguments: {'M': 10, 'alpha': 30, 'N': 5, 'L': 2, 'groups_num': 1, 'min_images_per_class': 10, 'backbone': 'efficientnet_v2_s', 'pretrain': 'imagenet', 'fc_output_dim': 512, 'use_amp16': True, 'augmentation_device': 'cuda', 'batch_size': 32, 'epochs_num': 3, 'iterations_per_epoch': 10000, 'lr': 1e-05, 'classifiers_lr': 0.01, 'brightness': 0.7, 'contrast': 0.7, 'hue': 0.5, 'saturation': 0.7, 'random_resized_crop': 0.5, 'infer_batch_size': 16, 'positive_dist_threshold': 25, 'resume_train': None, 'resume_model': None, 'device': 'cuda', 'seed': 0, 'num_workers': 8, 'dataset_folder': '/content/small', 'save_dir': 'efficientnet_v2_s_imagenet', 'val_set_folder': '/content/small/val', 'train_set_folder': '/content/small/train'}
# INFO:root:The outputs are being saved in logs/efficientnet_v2_s_imagenet/2023-01-13_15-49-34

# %% [markdown]
# # Test

# %% [markdown]
# ## Import model

# %%
# default is the one just trained
resume_model = f"/content/drive/MyDrive/project6/best_model.pth"

# %%
from CosPlace import test, datasets
from Team.model import network
from datasets.test_dataset import TestDataset

#### Model
model = network.GeoLocalizationNetV2(args.backbone, args.fc_output_dim, args.pretrain)

logging.info(f"There are {torch.cuda.device_count()} GPUs and {multiprocessing.cpu_count()} CPUs.")

if args.resume_model is not None:
  if os.path.exists(args.resume_model):
    resume_model = args.resume_model

if resume_model is not None:
  if not os.path.exists(resume_model):
    raise FileNotFoundError(f"Model {resume_model} not found.")

  logging.info(f"Loading model from {resume_model}")
  model_state_dict = torch.load(resume_model)
  model.load_state_dict(model_state_dict)
else:
    logging.info("WARNING: You didn't provide a path to resume the model (--resume_model parameter). " +
                 "Evaluation will be computed using randomly initialized weights.")

model = model.to(args.device)
# Out:
# INFO:faiss.loader:Loading faiss with AVX2 support.
# INFO:faiss.loader:Successfully loaded faiss with AVX2 support.
# Downloading: "https://download.pytorch.org/models/efficientnet_v2_s-dd5fe13b.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_v2_s-dd5fe13b.pth
#   0%|          | 0.00/82.7M [00:00<?, ?B/s]
# DEBUG:root:Train last two layers of EfficientNet, freeze the previous ones
# INFO:root:There are 1 GPUs and 2 CPUs.
# INFO:root:Loading model from /content/drive/MyDrive/project6/best_model.pth

# %% [markdown]
# ## Test on SF-XS

# %% [markdown]
# Test the model on the sf-xs (test) dataset.

# %%
# dataset_folder is the same of the training
test_set_folder = os.path.join(DATASET_FOLDER, "test")
if not os.path.exists(test_set_folder):
    raise FileNotFoundError(f"Test set folder {test_set_folder} not found")

test_ds = TestDataset(test_set_folder, queries_folder="queries_v1",
                      positive_dist_threshold=args.positive_dist_threshold)

recalls, recalls_str = test.test(args, test_ds, model)
logging.info(f"{test_ds}: {recalls_str}")

# recalls for csv file
sf_xs_r15 = f"{recalls[0]:.1f}/{recalls[1]:.1f}"
# Out:
# DEBUG:root:Extracting database descriptors for evaluation/testing
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100%|███████████████████████████████████████████████████████████| 1700/1700 [03:45<00:00,  7.55it/s]
# DEBUG:root:Extracting queries descriptors for evaluation/testing using batch size 1
# 100%|███████████████████████████████████████████████████████████| 1000/1000 [00:21<00:00, 45.82it/s]
# DEBUG:root:Calculating recalls
# INFO:root:< test - #q: 1000; #db: 27191 >: R@1: 50.5, R@5: 64.0, R@10: 68.1, R@20: 73.7

# %% [markdown]
# ## Test on Tokyo-XS

# %% [markdown]
# Test the model on the tokyo-xs dataset.

# %%
tokyo_xs_folder = "/content/tokyo_xs"
test_set_folder = os.path.join(tokyo_xs_folder, "test")
if not os.path.exists(test_set_folder):
    raise FileNotFoundError(f"Test set folder {test_set_folder} not found")

test_ds = TestDataset(test_set_folder,
                      positive_dist_threshold=args.positive_dist_threshold)

recalls, recalls_str = test.test(args, test_ds, model)
logging.info(f"{test_ds}: {recalls_str}")

# recalls for csv file
tokyo_xs_r15 = f"{recalls[0]:.1f}/{recalls[1]:.1f}"
# Out:
# DEBUG:root:Extracting database descriptors for evaluation/testing
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100%|█████████████████████████████████████████████████████████████| 799/799 [02:08<00:00,  6.22it/s]
# DEBUG:root:Extracting queries descriptors for evaluation/testing using batch size 1
# 100%|█████████████████████████████████████████████████████████████| 315/315 [00:07<00:00, 43.20it/s]
# DEBUG:root:Calculating recalls
# INFO:root:< test - #q: 315; #db: 12771 >: R@1: 70.5, R@5: 86.0, R@10: 90.2, R@20: 93.3

# %% [markdown]
# ## Test on Tokyo-Night

# %% [markdown]
# Test the model on the tokyo-night dataset.

# %%
tokyo_night_folder = "/content/tokyo-night/"
test_set_folder = os.path.join(tokyo_night_folder, "test")
if not os.path.exists(test_set_folder):
    raise FileNotFoundError(f"Test set folder {test_set_folder} not found")

test_ds = TestDataset(test_set_folder,
                      positive_dist_threshold=args.positive_dist_threshold)

recalls, recalls_str = test.test(args, test_ds, model)
logging.info(f"{test_ds}: {recalls_str}")

# recalls for csv file
tokyo_night_r15 = f"{recalls[0]:.1f}/{recalls[1]:.1f}"
# Out:
# DEBUG:root:Extracting database descriptors for evaluation/testing
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100%|█████████████████████████████████████████████████████████████| 799/799 [03:57<00:00,  3.36it/s]
# DEBUG:root:Extracting queries descriptors for evaluation/testing using batch size 1
# 100%|█████████████████████████████████████████████████████████████| 105/105 [00:04<00:00, 24.78it/s]
# DEBUG:root:Calculating recalls
# INFO:root:< test - #q: 105; #db: 12771 >: R@1: 68.6, R@5: 84.8, R@10: 85.7, R@20: 91.4

# %% [markdown]
# Test the model on the tokyo-night dataset, augmented with 10 random sf-xs images

# %%
tokyo_night_aug_folder = "/content/tokyo-night-aug/"
test_set_folder = os.path.join(tokyo_night_aug_folder, "test")
if not os.path.exists(test_set_folder):
    raise FileNotFoundError(f"Test set folder {test_set_folder} not found")

test_ds = TestDataset(test_set_folder,
                      positive_dist_threshold=args.positive_dist_threshold)

recalls, recalls_str = test.test(args, test_ds, model)
logging.info(f"{test_ds}: {recalls_str}")

# recalls for csv file
tokyo_night_aug_r15 = f"{recalls[0]:.1f}/{recalls[1]:.1f}"
# Out:
# DEBUG:root:Extracting database descriptors for evaluation/testing
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100%|█████████████████████████████████████████████████████████████| 799/799 [03:57<00:00,  3.36it/s]
# DEBUG:root:Extracting queries descriptors for evaluation/testing using batch size 1
# 100%|█████████████████████████████████████████████████████████████| 105/105 [00:04<00:00, 24.61it/s]
# DEBUG:root:Calculating recalls
# INFO:root:< test - #q: 105; #db: 12771 >: R@1: 69.5, R@5: 81.0, R@10: 85.7, R@20: 90.5

# %% [markdown]
# Test the model on the tokyo-night dataset, where the queries have been augmented with 10 random database images

# %%
tokyo_night_aug2_folder = "/content/tokyo-night-aug-2/"
test_set_folder = os.path.join(tokyo_night_aug2_folder, "test")
if not os.path.exists(test_set_folder):
    raise FileNotFoundError(f"Test set folder {test_set_folder} not found")

test_ds = TestDataset(test_set_folder,
                      positive_dist_threshold=args.positive_dist_threshold)

recalls, recalls_str = test.test(args, test_ds, model)
logging.info(f"{test_ds}: {recalls_str}")

# recalls for csv file
tokyo_night_aug2_r15 = f"{recalls[0]:.1f}/{recalls[1]:.1f}"
# Out:
# DEBUG:root:Extracting database descriptors for evaluation/testing
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100%|█████████████████████████████████████████████████████████████| 799/799 [03:58<00:00,  3.35it/s]
# DEBUG:root:Extracting queries descriptors for evaluation/testing using batch size 1
# 100%|█████████████████████████████████████████████████████████████| 105/105 [00:04<00:00, 21.21it/s]
# DEBUG:root:Calculating recalls
# INFO:root:< test - #q: 105; #db: 12771 >: R@1: 68.6, R@5: 81.0, R@10: 84.8, R@20: 90.5

# %% [markdown]
# # Save results

# %% [markdown]
# ## Create CSV with recalls

# %%
import csv
header = ["sf-xs (test)", "Tokyo-xs", "Tokyo-night"]
data = [sf_xs_r15, tokyo_xs_r15, tokyo_night_r15]

for h, d in zip(header, data):
  logging.info(f"{h}: {d}")

with open(f"/content/{SAVEDIR}_{start_time.strftime('%Y-%m-%d_%H-%M-%S')}.csv", "w") as f:
  writer = csv.writer(f)

  writer.writerow(header)
  writer.writerow(data)
logging.info(f"save table results to /content/{SAVEDIR}{start_time.strftime('%Y-%m-%d_%H-%M-%S')}.csv")
# Out:
# INFO:root:sf-xs (test): 50.5/64.0
# INFO:root:Tokyo-xs: 70.5/86.0
# INFO:root:Tokyo-night: 56.2/77.1
# INFO:root:save table results to /content/mobilenet_v3_large_imagenet2023-01-04_16-20-04.csv

# %% [markdown]
# ## Save on Drive

# %%
modelLocal = SAVEDIR

# %% [markdown]
# Save all data generated by this notebook in a specific folder in **PERSONAL** gdrive. Remember to copy inside shared_data of project drive

# %% [markdown]
# ### Run always

# %%
import os
from google.colab import drive

drive.mount('/content/drive')

# zip logs -> logs.zip
# !zip -r /content/drive/MyDrive/project_6/logs.zip /content/logs/
# zip cache -> cache.zip
if os.path.exists("/content/cache/"):
  # !zip -r /content/drive/MyDrive/project_6/cache.zip /content/cache/

# !cp "/content/{SAVEDIR}_{start_time.strftime('%Y-%m-%d_%H-%M-%S')}.csv" /content/drive/MyDrive/project6/

drive.flush_and_unmount()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# zip I/O error: No such file or directory
# zip error: Could not create output file (/content/drive/MyDrive/project_6/logs.zip)
# zip I/O error: No such file or directory
# zip error: Could not create output file (/content/drive/MyDrive/project_6/cache.zip)
